# %%
import numpy as np
import pandas as pd

# %%
FR8 = pd.read_csv("8_721Base2IR_L1_wls-var.csv")

# %%
FR8.iloc[:50,:]
# Out:
#     Levels Forecast_Methods Target_Service_Level Senario  \
# 0       10             LGBM                  90%    BASE
# 1       11             LGBM                  90%    BASE
# 2       12             LGBM                  90%    BASE
# 3       10             LGBM                  95%    BASE
# 4       11             LGBM                  95%    BASE
# 5       12             LGBM                  95%    BASE
# 6       10             LGBM                  99%    BASE
# 7       11             LGBM                  99%    BASE
# 8       12             LGBM                  99%    BASE
# 9       10          LGBM_BU                  90%    BASE
# 10      11          LGBM_BU                  90%    BASE
# 11      12          LGBM_BU                  90%    BASE
# 12      10          LGBM_BU                  95%    BASE
# 13      11          LGBM_BU                  95%    BASE
# 14      12          LGBM_BU                  95%    BASE
# ...

# %%
lgbm = FR8['Forecast_Methods'].str.contains('LGBM')
ets  = FR8['Forecast_Methods'].str.contains('ETS')
LGBM = FR8.loc[lgbm,:]
ETS  = FR8.loc[ets,:]

# %%
LGBM
# Out:
#      Levels Forecast_Methods Target_Service_Level  Senario  \
# 0        10             LGBM                  90%     BASE
# 1        11             LGBM                  90%     BASE
# 2        12             LGBM                  90%     BASE
# 3        10             LGBM                  95%     BASE
# 4        11             LGBM                  95%     BASE
# ..      ...              ...                  ...      ...
# 247      11        LGBM_MinT                  95%  MinT_IR
# 248      12        LGBM_MinT                  95%  MinT_IR
# 249      10        LGBM_MinT                  99%  MinT_IR
# 250      11        LGBM_MinT                  99%  MinT_IR
# 251      12        LGBM_MinT                  99%  MinT_IR
#
#      Achieved_Service_Level  Holding_Costs  Backlogging_Costs
# 0                  0.873483       6.512187           3.861173
# 1                  0.885083       3.548454           2.193455
# 2                  0.899572       1.953727           1.177339
# ...

# %%
LGBM.to_csv("8LGBM.csv", index = False)

# %%
ETS.to_csv("8ETS.csv", index = False)

# %%
LGBM
# Out:
#      Levels Forecast_Methods Target_Service_Level  Senario  \
# 0        10             LGBM                  90%     BASE
# 1        11             LGBM                  90%     BASE
# 2        12             LGBM                  90%     BASE
# 3        10             LGBM                  95%     BASE
# 4        11             LGBM                  95%     BASE
# ..      ...              ...                  ...      ...
# 247      11        LGBM_MinT                  95%  MinT_IR
# 248      12        LGBM_MinT                  95%  MinT_IR
# 249      10        LGBM_MinT                  99%  MinT_IR
# 250      11        LGBM_MinT                  99%  MinT_IR
# 251      12        LGBM_MinT                  99%  MinT_IR
#
#      Achieved_Service_Level  Holding_Costs  Backlogging_Costs
# 0                  0.873483       6.512187           3.861173
# 1                  0.885083       3.548454           2.193455
# 2                  0.899572       1.953727           1.177339
# ...
