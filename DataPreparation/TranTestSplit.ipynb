# %% [markdown]
# ## Processing Part I

# %%
import pandas as pd
import numpy as np
path_feature = 'D:/Jaypy/Semester 1, 2025/ExtensionHF/Data/Preprocessed/lvls_1_to_12.pkl'#_price_features
df = pd.read_pickle(f"{path_feature}")[['unique_id', 'ds']]#.drop(columns = ['sell_price'])

# %%
# path = 'D:/Jaypy/Semester 1, 2025/ExtensionHF/JayCode/processed_data.pkl'
#features = pd.read_pickle("features.pkl")
#price = pd.read_pickle("price.pkl")
#sprice = pd.read_pickle("sell_price.pkl")
df
# Out:
#                                                   unique_id    ds
# 0                                                     TOTAL     1
# 1                                                  TOTAL/CA     1
# 2                                                  TOTAL/TX     1
# 3                                                  TOTAL/WI     1
# 4                                               TOTAL/FOODS     1
# ...                                                     ...   ...
# 83152435  TOTAL/WI/WI_3/HOUSEHOLD/HOUSEHOLD_2/HOUSEHOLD_...  1941
# 83152436  TOTAL/WI/WI_3/HOUSEHOLD/HOUSEHOLD_2/HOUSEHOLD_...  1941
# 83152437  TOTAL/WI/WI_3/HOUSEHOLD/HOUSEHOLD_2/HOUSEHOLD_...  1941
# 83152438  TOTAL/WI/WI_3/HOUSEHOLD/HOUSEHOLD_2/HOUSEHOLD_...  1941
# 83152439  TOTAL/WI/WI_3/HOUSEHOLD/HOUSEHOLD_2/HOUSEHOLD_...  1941
#
# [83152440 rows x 2 columns]

# %%
df2 = df.sort_values(by = ['unique_id',"ds"])
df2
# Out:
#                                                   unique_id    ds
# 0                                                     TOTAL     1
# 42840                                                 TOTAL     2
# 85680                                                 TOTAL     3
# 128520                                                TOTAL     4
# 171360                                                TOTAL     5
# ...                                                     ...   ...
# 82981079  TOTAL/WI/WI_3/HOUSEHOLD/HOUSEHOLD_2/HOUSEHOLD_...  1937
# 83023919  TOTAL/WI/WI_3/HOUSEHOLD/HOUSEHOLD_2/HOUSEHOLD_...  1938
# 83066759  TOTAL/WI/WI_3/HOUSEHOLD/HOUSEHOLD_2/HOUSEHOLD_...  1939
# 83109599  TOTAL/WI/WI_3/HOUSEHOLD/HOUSEHOLD_2/HOUSEHOLD_...  1940
# 83152439  TOTAL/WI/WI_3/HOUSEHOLD/HOUSEHOLD_2/HOUSEHOLD_...  1941
#
# [83152440 rows x 2 columns]

# %%
pd.DataFrame(np.array(list(df2.index))).to_pickle("ts_INDEX.pkl")

# %%
pd.DataFrame(np.array(list(df2.index)))
# Out:
#                  0
# 0                0
# 1            42840
# 2            85680
# 3           128520
# 4           171360
# ...            ...
# 83152435  82981079
# 83152436  83023919
# 83152437  83066759
# 83152438  83109599
# 83152439  83152439
#
# [83152440 rows x 1 columns]

# %%
## Here is code for processing sell price orgnised by time
'''
from tqdm import tqdm
sprice = pd.DataFrame()
for i in tqdm(range(1941)):
    sprice = pd.concat([sprice, price[price['ds'] == i+1]], axis = 0)
sprice = sprice.reset_index(drop=True)
sprice["sell_price"].to_pickle("sell_price.pkl")'''
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████| 1941/1941 [11:01<00:00,  2.93it/s]

# %%
df = pd.concat([features, sprice],axis=1)
df
# Out:
#             ds      y  tm_d  tm_w  tm_m  tm_y  tm_wm  tm_dw  tm_w_end  \
# 0            1  32631    29     4     1     0      5      5         1
# 1            1  14195    29     4     1     0      5      5         1
# 2            1   9438    29     4     1     0      5      5         1
# 3            1   8998    29     4     1     0      5      5         1
# 4            1  23178    29     4     1     0      5      5         1
# ...        ...    ...   ...   ...   ...   ...    ...    ...       ...
# 83152435  1941      0    22    20     5     5      4      6         1
# 83152436  1941      0    22    20     5     5      4      6         1
# 83152437  1941      0    22    20     5     5      4      6         1
# 83152438  1941      0    22    20     5     5      4      6         1
# 83152439  1941      0    22    20     5     5      4      6         1
#
#          event_name_1 event_type_1 event_name_2 event_type_2 snap_CA snap_TX  \
# ...

# %% [markdown]
# ## Processing Part II

# %%
import pandas as pd
import numpy as np

# path = 'D:/Jaypy/Semester 1, 2025/ExtensionHF/JayCode/processed_data.pkl'
#features = pd.read_pickle("features.pkl")
#price = pd.read_pickle("price.pkl")
#sprice = pd.read_pickle("sell_price.pkl")
#pd.concat([features, sprice],axis=1).to_pickle("processed_data.pkl")
################################################################################
df = pd.read_pickle("processed_data.pkl")
id_idx = pd.read_pickle("ts_INDEX.pkl")

# %%
a = list(id_idx.iloc[:,0])

# %%
a
# Out:
# [0,
#  42840,
#  85680,
#  128520,
#  171360,
#  214200,
#  257040,
#  299880,
#  342720,
#  385560,
#  428400,
#  471240,
#  514080,
#  556920,
#  599760,
#  642600,
#  685440,
#  728280,
#  771120,
#  813960,
#  856800,
#  899640,
#  942480,
#  985320,
#  1028160,
#  1071000,
#  1113840,
#  1156680,
#  1199520,
#  1242360,
#  1285200,
#  1328040,
#  1370880,
#  1413720,
#  1456560,
#  1499400,
#  1542240,
#  1585080,
#  1627920,
#  1670760,
#  1713600,
#  1756440,
#  1799280,
#  1842120,
#  1884960,
#  1927800,
#  1970640,
#  2013480,
#  2056320,
#  2099160,
#  2142000,
#  2184840,
#  2227680,
#  2270520,
#  2313360,
#  2356200,
#  2399040,
#  2441880,
#  2484720,
#  2527560,
#  2570400,
#  2613240,
#  2656080,
#  2698920,
#  2741760,
#  2784600,
#  2827440,
#  2870280,
#  2913120,
#  2955960,
#  2998800,
#  3041640,
#  3084480,
#  3127320,
#  3170160,
#  3213000,
#  3255840,
#  3298680,
#  3341520,
#  3384360,
#  3427200,
#  3470040,
#  3512880,
#  3555720,
#  3598560,
# ...

# %%
id2 = pd.read_pickle("index_id.pkl").reindex(a)
id2
# Out:
# 0                                                       TOTAL
# 42840                                                   TOTAL
# 85680                                                   TOTAL
# 128520                                                  TOTAL
# 171360                                                  TOTAL
#                                   ...
# 82981079    TOTAL/WI/WI_3/HOUSEHOLD/HOUSEHOLD_2/HOUSEHOLD_...
# 83023919    TOTAL/WI/WI_3/HOUSEHOLD/HOUSEHOLD_2/HOUSEHOLD_...
# 83066759    TOTAL/WI/WI_3/HOUSEHOLD/HOUSEHOLD_2/HOUSEHOLD_...
# 83109599    TOTAL/WI/WI_3/HOUSEHOLD/HOUSEHOLD_2/HOUSEHOLD_...
# 83152439    TOTAL/WI/WI_3/HOUSEHOLD/HOUSEHOLD_2/HOUSEHOLD_...
# Name: unique_id, Length: 83152440, dtype: object

# %%
id2.to_pickle("id2_idx.pkl")

# %%
df = df.reindex(list(id_idx.iloc[:,0]))
df = pd.concat([id2,df], axis = 1)

# %%
df.to_pickle("data_with_uid.pkl")

# %% [markdown]
# ## Generate TestTrain sets:

# %%
df[df['ds'] >= 1914].to_pickle("test.pkl")
df[df['ds'] < 1914].to_pickle("train.pkl")

# %%
df[df['ds'] >= 1914]
# Out:
#                                                   unique_id    ds      y  \
# 81952920                                              TOTAL  1914  38793
# 81995760                                              TOTAL  1915  35487
# 82038600                                              TOTAL  1916  34445
# 82081440                                              TOTAL  1917  34732
# 82124280                                              TOTAL  1918  42896
# ...                                                     ...   ...    ...
# 82981079  TOTAL/WI/WI_3/HOUSEHOLD/HOUSEHOLD_2/HOUSEHOLD_...  1937      0
# 83023919  TOTAL/WI/WI_3/HOUSEHOLD/HOUSEHOLD_2/HOUSEHOLD_...  1938      0
# 83066759  TOTAL/WI/WI_3/HOUSEHOLD/HOUSEHOLD_2/HOUSEHOLD_...  1939      0
# 83109599  TOTAL/WI/WI_3/HOUSEHOLD/HOUSEHOLD_2/HOUSEHOLD_...  1940      0
# 83152439  TOTAL/WI/WI_3/HOUSEHOLD/HOUSEHOLD_2/HOUSEHOLD_...  1941      0
#
#           tm_d  tm_w  tm_m  tm_y  tm_wm  tm_dw  tm_w_end event_name_1  \
# ...
